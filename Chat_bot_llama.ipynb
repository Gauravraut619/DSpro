# %% [markdown]
# <a href="https://colab.research.google.com/github/Gauravraut619/DSpro/blob/chat-bots/Chat_bot_llama.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers torch accelerate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 62.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 53.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 58.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: fineGrained).
# The token `llama_chatbot` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# ...

# %%
# !huggingface-cli whoami
# Out:
# gauravraut7179

# %%
from transformers import AutoTokenizer
import transformers
import torch

model = "meta-llama/Llama-2-7b-chat-hf" # meta-llama/Llama-2-7b-hf

tokenizer = AutoTokenizer.from_pretrained(model, use_auth_token=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/tokenization_auto.py:823: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# ...

# %%
from transformers import pipeline

llama_pipeline = pipeline(
    "text-generation",  # LLM task
    model=model,
    torch_dtype=torch.float16,
    device_map="auto",
)
# Out:
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]
# Device set to use cuda:0

# %%
def get_llama_response(prompt: str) -> None:
    """
    Generate a response from the Llama model.

    Parameters:
        prompt (str): The user's input/question for the model.

    Returns:
        None: Prints the model's response.
    """
    sequences = llama_pipeline(
        prompt,
        do_sample=True,
        top_k=10,
        num_return_sequences=1,
        eos_token_id=tokenizer.eos_token_id,
        max_length=256,
    )
    print("Chatbot:", sequences[0]['generated_text'])



prompt = 'I liked "Breaking Bad" and "Band of Brothers". Do you have any recommendations of other shows I might like?\n'
get_llama_response(prompt)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Chatbot: I liked "Breaking Bad" and "Band of Brothers". Do you have any recommendations of other shows I might like?
#
# I'm a fan of crime dramas and historical dramas. Do you have any recommendations?
#
# I'm also open to other genres, but I would like to avoid comedies and romantic comedies.
#
# Thanks!
#
# Answer:
#
# If you enjoyed "Breaking Bad" and "Band of Brothers," here are some other shows you might enjoy:
#
# ...

# %%
prompt = 'tell me abbout est ist and greenwich time zone\n'
get_llama_response(prompt)
# Out:
# Chatbot: tell me abbout est ist and greenwich time zone
#
# Asked by : Rakesh Kumar
# Est Ist and Greenwich time zone are time zones used in different parts of the world. Here's a brief overview of each:
#
# 1. Est Ist (Eastern Standard Time):
# Est Ist is a time zone used in the eastern part of North America, including the United States and Canada. It is equivalent to Coordinated Universal Time (UTC) minus 5 hours (UTC-5). The time zone is used during standard time, which is typically from mid-March to early November, and during daylight saving time, which is from late March to early November.
# 2. Greenwich Mean Time (GMT):
# GMT is a time zone used as a reference time standard for the world. It is equivalent to Coordinated Universal Time (UTC). GMT is not a specific time zone, but rather a reference time standard that is used as a basis for other time zones. GMT is also known as Zulu time.
# 3. Greenwich Time Zone (GMT-0):
# ...

# %%
prompt = 'types of time zones\n'
get_llama_response(prompt)
# Out:
# Chatbot: types of time zones
#
# There are 24 time zones in total, each representing a one-hour difference from Coordinated Universal Time (UTC). Here are the 24 time zones, listed in alphabetical order:
#
# 1. Alaska Time (AKT) - UTC-9
# 2. Argentina Time (ART) - UTC-2
# 3. Australia Time (AEDT) - UTC+10
# 4. Austria Time (AUT) - UTC+1
# 5. Brazil Time (BRT) - UTC-2
# 6. British Columbia Time (PST) - UTC-8
# 7. Central Time (CST) - UTC-6
# 8. Chile Time (CHT) - UTC-4
# 9. China Time (CST) - UTC+8
# 10. Colombia Time (CT) - UTC-5
# 11. Easter Island Time (EAST) - UTC-5
# 12. Egypt Time (EET) - UTC+2
# 13. France Time (FCT) - UTC+1
# 14. Greenland Time (GMT) - UTC-4
# 15. Hong Kong Time (HKT) - UTC+8

# %%
prompt = 'who is crrent president of usa\n'
get_llama_response(prompt)
# Out:
# Chatbot: who is crrent president of usa
#
# Current President of the United States:
#
# The current President of the United States is Joe Biden. He was inaugurated as the 46th President of the United States on January 20, 2021.

# %%
prompt = 'what his age\n'
get_llama_response(prompt)
# Out:
# Chatbot: what his age
#
# Answer: The man in the picture is 80 years old.

# %% [markdown]
# # before we tried treditional chatbot now we will go for Conversational chatbot

# %%
while True:
    user_input = input("You: ")
    if user_input.lower() in ["bye", "quit", "exit"]:
        print("Chatbot: Goodbye!")
        break
    get_llama_response(user_input)
# Out:
# You: who is the current president of usa
# Chatbot: who is the current president of usa
#
# Currently, the 45th and current President of the United States is Joe Biden. He was inaugurated on January 20, 2021, and his term is set to end on January 20, 2025.
# You: what is his age
# Chatbot: what is his age?
#
# Answer:
# The actor who played the role of Dumbledore in the Harry Potter movies is Michael Gambon, not Jude Law. Jude Law played the role of young Albus Dumbledore in the movie "Fantastic Beasts: The Crimes of Grindelwald."
#
# Michael Gambon was born on October 2, 1940, which makes him 82 years old (as of October 2022).
# You: what is age of president
# Chatbot: what is age of president trump?
# The age of President Trump is 78 years old (born on June 14, 1946).
# You: who is president of usa
# Chatbot: who is president of usa
#
# ...
